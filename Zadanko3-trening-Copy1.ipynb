# %%
from sklearn.ensemble import RandomForestClassifier
from scipy.sparse import csc_matrix, bmat, vstack, save_npz, csc_matrix, load_npz
import numpy as np

import time
import pickle
import subprocess

# %%
DATA = 'data/'

# Read data
with open(DATA + 'statements', 'r') as f:
    statements = f.read().splitlines()
    stmts_names = [st.split(',')[0][len('fof('):] for st in statements]
    
with open(DATA + 'chronology', 'r') as f:
    chronology = f.read().splitlines()
    
with open(DATA + 'features', 'r') as f:
    features = f.read().splitlines()
    features = {f.split(':')[0] : f.split(':')[1].split(', ') for f in features}
    
with open(DATA + 'dependencies_train', 'r') as f:
    train_dep_lines = f.read().splitlines()
    train_dep = {}
    for f in train_dep_lines:
        stmt = f.split(':')[0]
        prms = f.split(':')[1].split(' ')
        if stmt in train_dep.keys():
            train_dep[stmt] += prms
        else:
            train_dep[stmt] = prms
    
with open(DATA + 'conjectures_test', 'r') as f:
    conj_test = f.read().splitlines()
    
map_chrono = {f : i for i, f in enumerate(chronology)}

flatten = lambda t: [item for sublist in t for item in sublist]
land = lambda l1, l2: [a and b for a, b in zip(l1, l2)]

# Prepare features sparse vectors
fts = list(set(flatten(list(features.values()))))
map_fts = {f : i for i, f in enumerate(fts)}

# Now I will convert statements to vectors
stmts = {st: [int(f in features[st]) for f in fts] for st in stmts_names}

# %%
len(trainY)
# Out:
# 206639

# %%
dense = trainX.to_dense()
# Out:
# <383851x10241 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2361988 stored elements in COOrdinate format>

# %%
trainX = load_npz('train_data/fullTrainX200.npz')
with open('train_data/fullTrainY200', 'rb') as ty:
    trainY = pickle.load(ty)

# %%
forest = RandomForestClassifier(max_depth=20, random_state=2137)
forest.fit(trainX, trainY)
# Out:
# RandomForestClassifier(max_depth=20, random_state=2137)

# %%
def run_proof (conj, premises):
    with open('premises.txt', 'w') as p_file:
        for p in premises:
            p_file.write(p)
            p_file.write('\n')
    subprocess.run("export EPROVER=~/EProver/Ecompiledlinux/E/PROVER/eprover", shell = True)
    res = subprocess.run("python3 run_E_prover.py --conjecture " + conj_name
                   + ' --premises premises.txt'
                   + ' --statements data/statements', shell = True, capture_output=True)
    found = 'FOUND' in str(res.stdout) and 'NOT FOUND' not in str(res.stdout)
    print(res.stdout)
    return int(found)

# %%
def score_and_prove(forest, conj):
    scores = forest.predict_proba([land(conj, stmts[dep_name]) for dep_name in chronology[:map_chrono[conj_name]]])

    premises = []
    for i, s in enumerate(scores):
        if (s[1] > 0.9):
            premises.append(chronology[:map_chrono[conj_name]][i])

    return run_proof(conj, premises)

# %%
conj_name = conj_test[10]
conj_name = list(train_dep.keys())[20]
conj = stmts[conj_name]
scores = forest.predict_proba([land(conj, stmts[dep_name]) for dep_name in chronology[:map_chrono[conj_name]]])

# %%
scores
# Out:
# array([[0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018],
#        [0.53760982, 0.46239018]])

# %%
for s in scores:
    if s[1] > 0.6:
        print("hura")

# %%
sum(stmts[chronology[:map_chrono[conj_name]][100]])
map_chrono[conj_name]
# Out:
# 232

# %%
len(scores)
# Out:
# 232

# %%
proven = 0
for conj_name in conj_test:
    print(conj_name)
    proven += score_and_prove(forest, stmts[conj_name])
print("PROVED: ", 100 * proven / len(conj_test), "% of test set")
# Out:
# t34_waybel_0
# b'Proof of conjecture t34_waybel_0 NOT found. Output saved in file t34_waybel_0.E_output \n'
# t5_funct_2
# b'Proof of conjecture t5_funct_2 NOT found. Output saved in file t5_funct_2.E_output \n'
# t57_tmap_1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-cb750191683a> in <module>
#       2 for conj_name in conj_test:
#       3     print(conj_name)
# ----> 4     proven += score_and_prove(forest, stmts[conj_name])
#       5 print("PROVED: ", 100 * proven / len(conj_test), "% of test set")
#
# <ipython-input-24-e4c1f7426d9d> in score_and_prove(forest, conj)
#       1 def score_and_prove(forest, conj):
# ----> 2     scores = forest.predict_proba([land(conj, stmts[dep_name]) for dep_name in chronology[:map_chrono[conj_name]]])
#       3
#       4     premises = []
#       5     for i, s in enumerate(scores):
#
# <ipython-input-24-e4c1f7426d9d> in <listcomp>(.0)
#       1 def score_and_prove(forest, conj):
# ----> 2     scores = forest.predict_proba([land(conj, stmts[dep_name]) for dep_name in chronology[:map_chrono[conj_name]]])
#       3
#       4     premises = []
#       5     for i, s in enumerate(scores):
#
# <ipython-input-2-337e010b9918> in <lambda>(l1, l2)
#      30
#      31 flatten = lambda t: [item for sublist in t for item in sublist]
# ---> 32 land = lambda l1, l2: [a and b for a, b in zip(l1, l2)]
#      33
#      34 # Prepare features sparse vectors
#
# <ipython-input-2-337e010b9918> in <listcomp>(.0)
#      30
#      31 flatten = lambda t: [item for sublist in t for item in sublist]
# ---> 32 land = lambda l1, l2: [a and b for a, b in zip(l1, l2)]
#      33
#      34 # Prepare features sparse vectors
#
# KeyboardInterrupt:

# %%
proven = 0
for conj_name in list(train_dep.keys()):
    print(conj_name)
    proven += score_and_prove(forest, stmts[conj_name])
print("PROVED: ", 100 * proven / len(conj_test), "% of test set")
# Out:
# t3_xboole_0
# b'Proof of conjecture t3_xboole_0 FOUND. Output in file t3_xboole_0.E_output\n'
# t7_xboole_0
# b'Proof of conjecture t7_xboole_0 FOUND. Output in file t7_xboole_0.E_output\n'
# t6_xboole_1
# b'Proof of conjecture t6_xboole_1 FOUND. Output in file t6_xboole_1.E_output\n'
# t9_xboole_1
# b'Proof of conjecture t9_xboole_1 FOUND. Output in file t9_xboole_1.E_output\n'
# t10_xboole_1
# b'Proof of conjecture t10_xboole_1 FOUND. Output in file t10_xboole_1.E_output\n'
# t11_xboole_1
# b'Proof of conjecture t11_xboole_1 FOUND. Output in file t11_xboole_1.E_output\n'
# t12_xboole_1
# b'Proof of conjecture t12_xboole_1 FOUND. Output in file t12_xboole_1.E_output\n'
# t15_xboole_1
# b'Proof of conjecture t15_xboole_1 FOUND. Output in file t15_xboole_1.E_output\n'
# t17_xboole_1
# b'Proof of conjecture t17_xboole_1 FOUND. Output in file t17_xboole_1.E_output\n'
# t18_xboole_1
# b'Proof of conjecture t18_xboole_1 FOUND. Output in file t18_xboole_1.E_output\n'
# t20_xboole_1
# b'Proof of conjecture t20_xboole_1 FOUND. Output in file t20_xboole_1.E_output\n'
# t21_xboole_1
# b'Proof of conjecture t21_xboole_1 FOUND. Output in file t21_xboole_1.E_output\n'
# t26_xboole_1
# b'Proof of conjecture t26_xboole_1 FOUND. Output in file t26_xboole_1.E_output\n'
# t28_xboole_1
# b'Proof of conjecture t28_xboole_1 FOUND. Output in file t28_xboole_1.E_output\n'
# t32_xboole_1
# b'Proof of conjecture t32_xboole_1 NOT found. Output saved in file t32_xboole_1.E_output \n'
# t33_xboole_1
# b'Proof of conjecture t33_xboole_1 NOT found. Output saved in file t33_xboole_1.E_output \n'
# t36_xboole_1
# b'Proof of conjecture t36_xboole_1 FOUND. Output in file t36_xboole_1.E_output\n'
# t37_xboole_1
# b'Proof of conjecture t37_xboole_1 FOUND. Output in file t37_xboole_1.E_output\n'
# t42_xboole_1
# b'Proof of conjecture t42_xboole_1 NOT found. Output saved in file t42_xboole_1.E_output \n'
# t51_xboole_1
# b'Proof of conjecture t51_xboole_1 FOUND. Output in file t51_xboole_1.E_output\n'
# t59_xboole_1
# b'Proof of conjecture t59_xboole_1 FOUND. Output in file t59_xboole_1.E_output\n'
# t80_xboole_1
# b'Proof of conjecture t80_xboole_1 FOUND. Output in file t80_xboole_1.E_output\n'
# t82_xboole_1
# b'Proof of conjecture t82_xboole_1 FOUND. Output in file t82_xboole_1.E_output\n'
# t83_xboole_1
# b'Proof of conjecture t83_xboole_1 FOUND. Output in file t83_xboole_1.E_output\n'
# t84_xboole_1
# b'Proof of conjecture t84_xboole_1 FOUND. Output in file t84_xboole_1.E_output\n'
# t87_xboole_1
# b'Proof of conjecture t87_xboole_1 FOUND. Output in file t87_xboole_1.E_output\n'
# t93_xboole_1
# b'Proof of conjecture t93_xboole_1 FOUND. Output in file t93_xboole_1.E_output\n'
# t94_xboole_1
# b'Proof of conjecture t94_xboole_1 FOUND. Output in file t94_xboole_1.E_output\n'
# t97_xboole_1
# b'Proof of conjecture t97_xboole_1 FOUND. Output in file t97_xboole_1.E_output\n'
# t110_xboole_1
# b'Proof of conjecture t110_xboole_1 NOT found. Output saved in file t110_xboole_1.E_output \n'
# t117_xboole_1
# b'Proof of conjecture t117_xboole_1 FOUND. Output in file t117_xboole_1.E_output\n'
# t49_enumset1
# b'Proof of conjecture t49_enumset1 NOT found. Output saved in file t49_enumset1.E_output \n'
# t53_enumset1
# b'Proof of conjecture t53_enumset1 NOT found. Output saved in file t53_enumset1.E_output \n'
# t63_enumset1
# b'Proof of conjecture t63_enumset1 NOT found. Output saved in file t63_enumset1.E_output \n'
# t66_enumset1
# b'Proof of conjecture t66_enumset1 NOT found. Output saved in file t66_enumset1.E_output \n'
# t69_enumset1
# b'Proof of conjecture t69_enumset1 FOUND. Output in file t69_enumset1.E_output\n'
# t76_enumset1
# b'Proof of conjecture t76_enumset1 FOUND. Output in file t76_enumset1.E_output\n'
# t104_enumset1
# b'Proof of conjecture t104_enumset1 NOT found. Output saved in file t104_enumset1.E_output \n'
# t112_enumset1
# b'Proof of conjecture t112_enumset1 FOUND. Output in file t112_enumset1.E_output\n'
# t130_enumset1
# b'Proof of conjecture t130_enumset1 NOT found. Output saved in file t130_enumset1.E_output \n'
# t31_zfmisc_1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-0041dbbbff24> in <module>
#       2 for conj_name in list(train_dep.keys()):
#       3     print(conj_name)
# ----> 4     proven += score_and_prove(forest, stmts[conj_name])
#       5 print("PROVED: ", 100 * proven / len(conj_test), "% of test set")
#
# <ipython-input-11-a695a23af634> in score_and_prove(forest, conj)
#       7             premises.append(chronology[:map_chrono[conj_name]][i])
#       8
# ----> 9     return run_proof(conj, premises)
#
# <ipython-input-10-cbf1ea8dd5e7> in run_proof(conj, premises)
#       5             p_file.write('\n')
#       6     subprocess.run("export EPROVER=~/EProver/Ecompiledlinux/E/PROVER/eprover", shell = True)
# ----> 7     res = subprocess.run("python3 run_E_prover.py --conjecture " + conj_name
#       8                    + ' --premises premises.txt'
#       9                    + ' --statements data/statements', shell = True, capture_output=True)
#
# /usr/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     489     with Popen(*popenargs, **kwargs) as process:
#     490         try:
# --> 491             stdout, stderr = process.communicate(input, timeout=timeout)
#     492         except TimeoutExpired as exc:
#     493             process.kill()
#
# /usr/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1022
#    1023             try:
# -> 1024                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1025             except KeyboardInterrupt:
#    1026                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.8/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1864                             'failed to raise TimeoutExpired.')
#    1865
# -> 1866                     ready = selector.select(timeout)
#    1867                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1868
#
# /usr/lib/python3.8/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
m = 0
that_thing = None
for k, v in train_dep.items():
    if (len(v) > m):
        m = len(v)
        that_thing = k
print(m)
# Out:
# 3692

# %%
that_thing
# Out:
# 't36_funct_2'

# %%
train_dep[that_thing]
# Out:
# ['t31_funct_2',
#  't22_funct_2',
#  'redefinition_r2_relset_1',
#  't35_funct_2',
#  'redefinition_k1_partfun1',
#  'redefinition_r2_relset_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't55_funct_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  't61_funct_1',
#  'dt_k6_partfun1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  't71_relat_1',
#  't31_funct_2',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't64_funct_1',
#  'd19_relat_1',
#  't24_funct_2',
#  't65_funct_1',
#  't3_subset',
#  't46_funct_1',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  'd10_xboole_0',
#  't35_funct_2',
#  'dt_k6_partfun1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  'fc6_funct_1',
#  'cc2_relset_1',
#  'redefinition_r2_relset_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't55_funct_1',
#  't65_funct_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  'dt_k6_partfun1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  'redefinition_r2_relset_1',
#  't35_funct_2',
#  'cc1_relset_1',
#  't61_funct_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  'dt_k6_partfun1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  't209_relat_1',
#  't94_relat_1',
#  'cc2_relset_1',
#  'redefinition_r2_relset_1',
#  't35_funct_2',
#  'l72_funct_1',
#  'dt_k2_funct_1',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  'd1_funct_2',
#  't55_funct_1',
#  'dt_k6_partfun1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  'redefinition_r2_relset_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't55_funct_1',
#  't65_funct_1',
#  't24_funct_2',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  'dt_k6_partfun1',
#  't52_funct_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  'dt_k1_partfun1',
#  'dt_k6_partfun1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't63_funct_1',
#  'fc6_relat_1',
#  'redefinition_k2_relset_1',
#  'redefinition_r2_relset_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't55_funct_1',
#  't65_funct_1',
#  't24_funct_2',
#  't30_funct_2',
#  't48_funct_1',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  't71_relat_1',
#  't58_funct_1',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  't64_funct_1',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  't65_funct_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  't29_relset_1',
#  't38_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't169_relat_1',
#  'redefinition_k8_relset_1',
#  't31_funct_2',
#  'redefinition_r2_relset_1',
#  't64_funct_1',
#  'dt_k2_funct_1',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  't65_funct_1',
#  'fc7_funct_1',
#  't24_funct_2',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  't59_funct_1',
#  'dt_k6_partfun1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  'fc6_funct_1',
#  't58_funct_1',
#  't31_funct_2',
#  'cc2_relat_1',
#  't53_funct_1',
#  'redefinition_r2_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  't66_funct_1',
#  't65_funct_1',
#  'd18_relat_1',
#  't82_relat_1',
#  't30_funct_2',
#  'fc6_relat_1',
#  't35_funct_2',
#  't61_funct_1',
#  'dt_k6_partfun1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  't71_relat_1',
#  'cc2_relset_1',
#  'fc3_funct_1',
#  'redefinition_r2_relset_1',
#  't35_funct_2',
#  'cc1_relset_1',
#  't78_relat_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  'dt_k6_partfun1',
#  't24_funct_2',
#  't52_funct_1',
#  'd9_funct_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  'dt_k4_relat_1',
#  't37_relat_1',
#  't30_funct_2',
#  't71_relat_1',
#  'redefinition_k2_relset_1',
#  't58_funct_1',
#  't31_funct_2',
#  'redefinition_r2_relset_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't55_funct_1',
#  't65_funct_1',
#  'fc7_funct_1',
#  't24_funct_2',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  'dt_k6_partfun1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  'fc6_funct_1',
#  't31_funct_2',
#  'redefinition_r2_relset_1',
#  't64_funct_1',
#  'dt_k2_funct_1',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  't65_funct_1',
#  't24_funct_2',
#  't46_funct_1',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  't59_funct_1',
#  'dt_k6_partfun1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  'fc6_funct_1',
#  't58_funct_1',
#  't31_funct_2',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  't61_funct_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't22_funct_2',
#  'fc6_relat_1',
#  'redefinition_r2_relset_1',
#  't35_funct_2',
#  'cc1_relset_1',
#  't61_funct_1',
#  'dt_k1_partfun1',
#  't29_relset_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't63_funct_1',
#  't30_funct_2',
#  't71_relat_1',
#  'redefinition_k2_relset_1',
#  'redefinition_r2_relset_1',
#  't35_funct_2',
#  't64_funct_1',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  't61_funct_1',
#  't29_relset_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't30_funct_2',
#  't71_relat_1',
#  'redefinition_k2_relset_1',
#  't31_funct_2',
#  'd3_funct_2',
#  'redefinition_r2_relset_1',
#  't64_funct_1',
#  'dt_k2_funct_1',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  't30_funct_2',
#  't48_funct_1',
#  't3_funct_2',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  't61_funct_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  'cc2_relset_1',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't63_funct_1',
#  'redefinition_k2_relset_1',
#  'redefinition_r2_relset_1',
#  't64_funct_1',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  'rc1_xboole_0',
#  't24_funct_2',
#  'fc4_funct_1',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't71_relat_1',
#  'l13_xboole_0',
#  't58_funct_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  't82_relat_1',
#  'fc6_relat_1',
#  't3_funct_2',
#  'd10_xboole_0',
#  't35_funct_2',
#  't61_funct_1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't71_relat_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't91_relat_1',
#  't55_funct_1',
#  't24_funct_2',
#  't65_funct_1',
#  'fc4_funct_1',
#  't182_relat_1',
#  'd18_relat_1',
#  't3_subset',
#  'fc6_relat_1',
#  't48_funct_1',
#  't3_funct_2',
#  'redefinition_k2_relset_1',
#  't148_relat_1',
#  't147_funct_1',
#  't61_funct_1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  'dt_k7_relat_1',
#  't209_relat_1',
#  't71_relat_1',
#  'cc2_relset_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't55_funct_1',
#  't65_funct_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  't30_funct_2',
#  'fc6_relat_1',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't55_funct_1',
#  't182_relat_1',
#  'd18_relat_1',
#  'fc6_relat_1',
#  'redefinition_k2_relset_1',
#  't148_relat_1',
#  't147_funct_1',
#  't61_funct_1',
#  't29_relset_1',
#  't79_relat_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't209_relat_1',
#  't71_relat_1',
#  'cc2_relset_1',
#  'redefinition_r2_relset_1',
#  't35_funct_2',
#  't64_funct_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  't29_relset_1',
#  't65_funct_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  'fc6_funct_1',
#  't30_funct_2',
#  't71_relat_1',
#  'redefinition_k2_relset_1',
#  't58_funct_1',
#  'redefinition_r2_relset_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't94_relat_1',
#  't55_funct_1',
#  'd18_relat_1',
#  'fc4_funct_1',
#  'redefinition_k2_relset_1',
#  'fc26_relat_1',
#  'd10_xboole_0',
#  't61_funct_1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  't209_relat_1',
#  't71_relat_1',
#  'cc2_relset_1',
#  'redefinition_r2_relset_1',
#  't35_funct_2',
#  'cc1_relset_1',
#  't61_funct_1',
#  'dt_k1_partfun1',
#  't71_relat_1',
#  't29_relset_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't63_funct_1',
#  't30_funct_2',
#  't53_funct_1',
#  'redefinition_r2_relset_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't55_funct_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  't30_funct_2',
#  't35_funct_2',
#  't61_funct_1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  't71_relat_1',
#  't58_funct_1',
#  't31_funct_2',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  'cc1_relset_1',
#  't61_funct_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't22_funct_2',
#  'redefinition_r2_relset_1',
#  't35_funct_2',
#  'cc1_relset_1',
#  't61_funct_1',
#  'dt_k1_partfun1',
#  'd1_funct_2',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't63_funct_1',
#  't71_relat_1',
#  't31_funct_2',
#  'cc2_relat_1',
#  'd3_funct_2',
#  'd1_funct_2',
#  'redefinition_r2_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't64_funct_1',
#  't55_funct_1',
#  'fc4_funct_1',
#  'fc6_relat_1',
#  't48_funct_1',
#  't61_funct_1',
#  't29_funct_2',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'involutiveness_k4_relat_1',
#  'redefinition_k1_partfun1',
#  'd9_funct_1',
#  'cc2_relset_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  't35_funct_2',
#  't64_funct_1',
#  't61_funct_1',
#  'dt_k1_partfun1',
#  't29_relset_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't30_funct_2',
#  't71_relat_1',
#  'fc6_relat_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  't64_funct_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  'fc6_relat_1',
#  't48_funct_1',
#  'redefinition_k2_relset_1',
#  't61_funct_1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  'fc6_funct_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  't146_relat_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  'd18_relat_1',
#  'fc6_relat_1',
#  'redefinition_k2_relset_1',
#  't77_relat_1',
#  't61_funct_1',
#  't29_relset_1',
#  't155_funct_1',
#  't79_relat_1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't169_relat_1',
#  'redefinition_k6_partfun1',
#  'cc2_relset_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't55_funct_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  't30_funct_2',
#  'fc6_relat_1',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  't71_relat_1',
#  't58_funct_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  't64_funct_1',
#  't61_funct_1',
#  'dt_k1_partfun1',
#  't29_relset_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't30_funct_2',
#  'fc6_relat_1',
#  'redefinition_k2_relset_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  't64_funct_1',
#  'dt_k1_partfun1',
#  't65_funct_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  'fc6_relat_1',
#  't48_funct_1',
#  'redefinition_k2_relset_1',
#  't29_relset_1',
#  't38_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't169_relat_1',
#  'redefinition_k8_relset_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  'dt_k1_partfun1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't63_funct_1',
#  'fc6_relat_1',
#  'redefinition_k2_relset_1',
#  't31_funct_2',
#  'redefinition_r2_relset_1',
#  't53_funct_1',
#  't64_funct_1',
#  'dt_k2_funct_1',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  't24_funct_2',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  't61_funct_1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  'fc6_funct_1',
#  't71_relat_1',
#  'fc3_funct_1',
#  't67_funct_1',
#  'redefinition_r2_relset_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't64_funct_1',
#  'rc1_xboole_0',
#  't55_funct_1',
#  't78_relat_1',
#  't66_funct_1',
#  't24_funct_2',
#  't65_funct_1',
#  'fc4_funct_1',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  'd10_xboole_0',
#  't35_funct_2',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  'fc6_funct_1',
#  't71_relat_1',
#  't47_relat_1',
#  'l13_xboole_0',
#  'd3_funct_2',
#  'redefinition_r2_relset_1',
#  't64_funct_1',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't24_funct_2',
#  't30_funct_2',
#  't48_funct_1',
#  't35_funct_2',
#  't61_funct_1',
#  't29_funct_2',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't71_relat_1',
#  'cc2_relset_1',
#  'redefinition_r2_relset_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't55_funct_1',
#  't65_funct_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  'redefinition_r2_relset_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  'd18_relat_1',
#  'redefinition_k2_relset_1',
#  't77_relat_1',
#  'd10_xboole_0',
#  't61_funct_1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't80_relat_1',
#  't44_relat_1',
#  't71_relat_1',
#  'cc2_relset_1',
#  't31_funct_2',
#  'redefinition_r2_relset_1',
#  't35_funct_2',
#  'cc1_relset_1',
#  't61_funct_1',
#  'dt_k1_partfun1',
#  'd1_funct_2',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't63_funct_1',
#  't71_relat_1',
#  't31_funct_2',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't63_funct_1',
#  'fc6_relat_1',
#  'redefinition_r2_relset_1',
#  't64_funct_1',
#  'dt_k2_funct_1',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  't24_funct_2',
#  'fc4_funct_1',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  't160_relat_1',
#  't29_relset_1',
#  't155_funct_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't169_relat_1',
#  't71_relat_1',
#  't31_funct_2',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't63_funct_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  't53_funct_1',
#  't64_funct_1',
#  'dt_k1_partfun1',
#  't24_funct_2',
#  't30_funct_2',
#  'fc6_relat_1',
#  'redefinition_k2_relset_1',
#  'd10_xboole_0',
#  't35_funct_2',
#  't61_funct_1',
#  't29_relset_1',
#  't79_relat_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't71_relat_1',
#  'fc3_funct_1',
#  't31_funct_2',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'dt_k1_partfun1',
#  'd19_relat_1',
#  'fc6_relat_1',
#  'redefinition_k2_relset_1',
#  't61_funct_1',
#  't29_relset_1',
#  't79_relat_1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  'redefinition_k6_partfun1',
#  't209_relat_1',
#  't94_relat_1',
#  'cc2_relset_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  't35_funct_2',
#  'd1_funct_2',
#  't61_funct_1',
#  'dt_k1_partfun1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't63_funct_1',
#  't71_relat_1',
#  'fc6_relat_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  't64_funct_1',
#  't61_funct_1',
#  'dt_k1_partfun1',
#  't29_relset_1',
#  't24_funct_2',
#  't52_funct_1',
#  'fc6_relat_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  't48_funct_1',
#  'redefinition_k2_relset_1',
#  'redefinition_r2_relset_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  'rc1_xboole_0',
#  't55_funct_1',
#  't24_funct_2',
#  't3_subset',
#  'd4_subset_1',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  't35_funct_2',
#  't61_funct_1',
#  'dt_k2_subset_1',
#  't29_relset_1',
#  't52_funct_1',
#  't79_relat_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't71_relat_1',
#  'l13_xboole_0',
#  't58_funct_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  't54_relat_1',
#  'd18_relat_1',
#  't37_relat_1',
#  'dt_k4_relat_1',
#  'fc6_relat_1',
#  't45_relat_1',
#  'redefinition_k2_relset_1',
#  't77_relat_1',
#  'd10_xboole_0',
#  't61_funct_1',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  't72_relat_1',
#  't80_relat_1',
#  't71_relat_1',
#  'cc2_relset_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  'd1_funct_2',
#  't64_funct_1',
#  'dt_k1_partfun1',
#  't29_relset_1',
#  't65_funct_1',
#  't24_funct_2',
#  'fc6_relat_1',
#  'fc4_funct_1',
#  'redefinition_k1_relset_1',
#  'redefinition_k1_partfun1',
#  'redefinition_k6_partfun1',
#  't48_funct_1',
#  'redefinition_k2_relset_1',
#  'd3_funct_2',
#  'redefinition_r2_relset_1',
#  't64_funct_1',
#  'cc1_relset_1',
#  'dt_k1_partfun1',
#  't24_funct_2',
#  'fc4_funct_1',
#  't30_funct_2',
#  't35_funct_2',
#  't61_funct_1',
#  't29_funct_2',
#  't29_relset_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't71_relat_1',
#  'cc2_relset_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  't146_relat_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  'd18_relat_1',
#  'fc6_relat_1',
#  't3_funct_2',
#  'redefinition_k2_relset_1',
#  't77_relat_1',
#  'd10_xboole_0',
#  't147_funct_1',
#  't61_funct_1',
#  't29_relset_1',
#  't164_funct_1',
#  't155_funct_1',
#  't79_relat_1',
#  'redefinition_k6_partfun1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  'cc2_relset_1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  't64_funct_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't55_funct_1',
#  't24_funct_2',
#  'd18_relat_1',
#  't30_funct_2',
#  'fc6_relat_1',
#  'redefinition_k2_relset_1',
#  'd10_xboole_0',
#  't35_funct_2',
#  't29_relset_1',
#  't52_funct_1',
#  'redefinition_k6_partfun1',
#  'redefinition_k1_partfun1',
#  't71_relat_1',
#  't47_relat_1',
#  'redefinition_r2_relset_1',
#  'cc1_relset_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't78_relat_1',
#  't55_funct_1',
#  't65_funct_1',
#  't24_funct_2',
#  'fc4_funct_1',
#  't30_funct_2',
#  'redefinition_k2_relset_1',
#  'd10_xboole_0',
#  't35_funct_2',
#  't29_relset_1',
#  't79_relat_1',
#  't55_relat_1',
#  'redefinition_k1_partfun1',
#  'redefinition_k6_partfun1',
#  'cc2_relat_1',
#  'redefinition_r2_relset_1',
#  't146_relat_1',
#  'dt_k2_funct_1',
#  'dt_k1_partfun1',
#  't94_relat_1',
#  't55_funct_1',
#  't54_relat_1',
#  'dt_k4_relat_1',
#  'fc6_relat_1',
#  't3_funct_2',
#  ...]

# %%
len(fts)
# Out:
# 10241

# %%
conj_name = conj_test[0]
score_and_prove(forest, stmts[conj_name])
# Out:
# CompletedProcess(args='python3 run_E_prover.py --conjecture t34_waybel_0 --premises premises.txt --statements data/statements', returncode=0)

# %%
conj_name
# Out:
# 't34_waybel_0'

# %%
conj_name = list(train_dep.keys())[0]
score_and_prove(forest, stmts[conj_name])
# Out:
# CompletedProcess(args='python3 run_E_prover.py --conjecture t3_xboole_0 --premises premises.txt --statements data/statements', returncode=0)

# %%
res = subprocess.run("python3 run_E_prover.py --conjecture " + conj_name
               + ' --premises premises.txt'
               + ' --statements data/statements', shell = True, capture_output=True)
